# %% [markdown]
# ## MCP HTTP

# %%
# uvicorn duckduckgo_mcp_http:app --reload

import requests

query = "Python MCP SDK"
res = requests.get(f"http://127.0.0.1:8000/search?query={query}")

try:
    results = res.json()
except ValueError:
    print("Error: Response is not valid JSON.")
    results = []

# Debugging: see what the response looks like
print("Full response:", results)
print("Type of response:", type(results))

# Check if the response is a dict with a 'results' key
if isinstance(results, dict) and "results" in results:
    results = results["results"]

# Now iterate over results
for i, r in enumerate(results, 1):
    # If r is a dict with expected keys
    if isinstance(r, dict):
        title = r.get("title", "No title")
        url = r.get("url", "No URL")
        snippet = r.get("snippet", "")
        print(f"{i}. {title} ({url})")
        if snippet:
            print(f"   {snippet}\n")
    # If r is a string
    elif isinstance(r, str):
        print(f"{i}. {r}\n")
    else:
        print(f"{i}. Unrecognized format: {r}\n")
# Out:
# Full response: {'content': [{'type': 'text', 'text': '[\n  {\n    "title": "MCP Python SDK - GitHub",\n    "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fgithub.com%2Fmodelcontextprotocol%2Fpython%2Dsdk&rut=b754ce8db898ccb4be380be62ccee95fbe83a617dead012ae5c43872cc141806"\n  },\n  {\n    "title": "mcp \\u00b7 PyPI",\n    "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fpypi.org%2Fproject%2Fmcp%2F&rut=fd7adf7988ac12b5a33784d47e8c35a61301fe851c9947ff0c74ebac6c181af6"\n  },\n  {\n    "title": "SDKs - Model Context Protocol",\n    "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fmodelcontextprotocol.io%2Fdocs%2Fsdk&rut=f0c6d0187900bd01868fb80ef03a00f44f9ce278b4096866f23c220dd71c1438"\n  },\n  {\n    "title": "Building MCP Servers \\u2014 Model Context Protocol (MCP) Python SDK ...",\n    "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fanish%2Dnatekar.github.io%2Fmcp_docs%2Fserver%2Dguide.html&rut=53d339d97df4fecbbba73bcce83e7d8a940897b3c43f88db669c951d9b4f16ec"\n  },\n  {\n    "title": "python-sdk - MCPdb",\n    "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fmcpdb.org%2Fmcps%2Fpython%2Dsdk&rut=49196b86642132532106ff0377f1e7f06914cb1fa5e692cfe345b7dd4ff8490e"\n  },\n  {\n    "title": "Build a Python MCP Client to Test Servers From Your Terminal",\n    "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Frealpython.com%2Fpython%2Dmcp%2Dclient%2F&rut=8424d2486d445b43c9624edc91be0c801efb5fc445c06c4540f661c6a3d72b37"\n  },\n  {\n    "title": "modelcontextprotocol/python-sdk: Official MCP Python Library",\n    "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fhellogithub.com%2Fen%2Frepository%2F7c8c265fdfad4269bafa68ba4172860b&rut=4be063b8f1079152bb4a0c75e9f78a0163919429c294ad1eec81bde2b18d1cec"\n  },\n  {\n    "title": "Get Started with MCP Development | SDKs, Templates & Resources",\n    "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fwww.mcphub.ai%2Fmcp%2Ddev&rut=2ff1a39fc8594e092427d508e18e917e962017f1b38c1075424b961da93af9c1"\n  },\n  {\n    "title": "Building a Simple MCP Server in Python Using the MCP Python SDK",\n    "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fruslanmv.com%2Fblog%2FSimple%2DMCP%2DServer%2Dwith%2DPython&rut=23a1bb73c277a6f60f7d15c30a58953fbde4992a5de2d08b41e52ffc717f082b"\n  },\n  {\n    "title": "AI-App/ModelContextProtocol.Python-SDK - GitHub",\n    "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fgithub.com%2FAI%2DApp%2FModelContextProtocol.Python%2DSDK&rut=3a75dd5347e99b2b7fbf5ea61bdabfcbe9227b074707b6c1ac48ae23092f0e50"\n  }\n]'}]}
# Type of response: <class 'dict'>
# 1. content

# %%
results
# Out:
# {'content': [{'type': 'text',
#    'text': '[\n  {\n    "title": "MCP Python SDK - GitHub",\n    "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fgithub.com%2Fmodelcontextprotocol%2Fpython%2Dsdk&rut=b754ce8db898ccb4be380be62ccee95fbe83a617dead012ae5c43872cc141806"\n  },\n  {\n    "title": "mcp \\u00b7 PyPI",\n    "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fpypi.org%2Fproject%2Fmcp%2F&rut=fd7adf7988ac12b5a33784d47e8c35a61301fe851c9947ff0c74ebac6c181af6"\n  },\n  {\n    "title": "SDKs - Model Context Protocol",\n    "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fmodelcontextprotocol.io%2Fdocs%2Fsdk&rut=f0c6d0187900bd01868fb80ef03a00f44f9ce278b4096866f23c220dd71c1438"\n  },\n  {\n    "title": "Building MCP Servers \\u2014 Model Context Protocol (MCP) Python SDK ...",\n    "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fanish%2Dnatekar.github.io%2Fmcp_docs%2Fserver%2Dguide.html&rut=53d339d97df4fecbbba73bcce83e7d8a940897b3c43f88db669c951d9b4f16ec"\n  },\n  {\n    "title": "python-sdk - MCPdb",\n    "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fmcpdb.org%2Fmcps%2Fpython%2Dsdk&rut=49196b86642132532106ff0377f1e7f06914cb1fa5e692cfe345b7dd4ff8490e"\n  },\n  {\n    "title": "Build a Python MCP Client to Test Servers From Your Terminal",\n    "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Frealpython.com%2Fpython%2Dmcp%2Dclient%2F&rut=8424d2486d445b43c9624edc91be0c801efb5fc445c06c4540f661c6a3d72b37"\n  },\n  {\n    "title": "modelcontextprotocol/python-sdk: Official MCP Python Library",\n    "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fhellogithub.com%2Fen%2Frepository%2F7c8c265fdfad4269bafa68ba4172860b&rut=4be063b8f1079152bb4a0c75e9f78a0163919429c294ad1eec81bde2b18d1cec"\n  },\n  {\n    "title": "Get Started with MCP Development | SDKs, Templates & Resources",\n    "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fwww.mcphub.ai%2Fmcp%2Ddev&rut=2ff1a39fc8594e092427d508e18e917e962017f1b38c1075424b961da93af9c1"\n  },\n  {\n    "title": "Building a Simple MCP Server in Python Using the MCP Python SDK",\n    "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fruslanmv.com%2Fblog%2FSimple%2DMCP%2DServer%2Dwith%2DPython&rut=23a1bb73c277a6f60f7d15c30a58953fbde4992a5de2d08b41e52ffc717f082b"\n  },\n  {\n    "title": "AI-App/ModelContextProtocol.Python-SDK - GitHub",\n    "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fgithub.com%2FAI%2DApp%2FModelContextProtocol.Python%2DSDK&rut=3a75dd5347e99b2b7fbf5ea61bdabfcbe9227b074707b6c1ac48ae23092f0e50"\n  }\n]'}]}

# %% [markdown]
# ## MCP Server

# %%
#this is for duckduckgo_mcp_server file

from fastmcp import Client
global resp
async def call_search():
    global resp
    async with Client("http://127.0.0.1:8000/mcp") as client:
        resp = await client.call_tool("duckduckgo_search", {"query":"mcp servers working code"})
        # print(resp)

await call_search()

# %%
resp
# Out:
# CallToolResult(content=[TextContent(type='text', text='{\n  "title": "Use MCP servers in VS Code - Visual Studio Code",\n  "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fcode.visualstudio.com%2Fdocs%2Fcopilot%2Fcustomization%2Fmcp%2Dservers&rut=1573ce17ef141aa0e1cea917c9f9326fd7194158c250f5de44fda89bb49a9f63",\n  "snippet": "Learn how to configure and use Model Context Protocol (MCP)serverswith GitHub Copilot in Visual StudioCode."\n}', annotations=None, meta=None), TextContent(type='text', text='{\n  "title": "10 Microsoft MCP Servers to Accelerate Your Development Workflow",\n  "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fdeveloper.microsoft.com%2Fblog%2F10%2Dmicrosoft%2Dmcp%2Dservers%2Dto%2Daccelerate%2Dyour%2Ddevelopment%2Dworkflow&rut=f217d48669387a2592b08015774f7e018a8562ecd0f30c4aa8c9ebbe6bc2d020",\n  "snippet": "Here are 10MCPserversthat Microsoft has built that we\'ve found particularly useful in our daily work - tools that solve real problems and speed up common development tasks. This isn\'t a comprehensive ranking, but rather a practical guide based on our team\'s experience with theseserversin real-world scenarios."\n}', annotations=None, meta=None), TextContent(type='text', text='{\n  "title": "How to add 100+ MCP servers to VS Code in minutes",\n  "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fcomposio.dev%2Fblog%2Fhow%2Dto%2Dadd%2D100%2Dmcp%2Dservers%2Dto%2Dvs%2Dcode%2Din%2Dminutes&rut=d6f2fd3e131ad2e83dc71095d53ff4026cc7b305c3d3fbd86fff5cea3a57a015",\n  "snippet": "2. EnableMCPin VSCodeVSCode, by default, has theMCPserverenabled. To verify hit CTRL+SHIFT+P (Windows & Linux) / CMD+SHIFT+P (Mac) and searchMCP. 3. Add LocalMCPServersto VSCodeClickMCP: AddMCPServer& Select Command (stdio). Now follow the instructions carefully on all tabs! → Enter Command: Enter the command to run theserver."\n}', annotations=None, meta=None), TextContent(type='text', text='{\n  "title": "GitHub - microsoft/azure-devops-mcp: The MCP server for Azure DevOps ...",\n  "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fgithub.com%2Fmicrosoft%2Fazure%2Ddevops%2Dmcp&rut=48ec0564a15b428286132156481d3a5c5085f202558db58e40aa17532f7e0239",\n  "snippet": "Easily install the Azure DevOpsMCPServerfor VSCodeor VSCodeInsiders: This TypeScript project provides a localMCPserverfor Azure DevOps, enabling you to perform a wide range of Azure DevOps tasks directly from yourcodeeditor."\n}', annotations=None, meta=None), TextContent(type='text', text='{\n  "title": "How to Set Up and Use VSCode MCP Server - Medium",\n  "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fmedium.com%2Ftowards%2Dagi%2Fhow%2Dto%2Dset%2Dup%2Dand%2Duse%2Dvscode%2Dmcp%2Dserver%2D352c1e6f42e9&rut=61173c33488416f3a70ba5d40352d65d380043bba2b421c2cd1e799939532d53",\n  "snippet": "VSCodeMCPServerrepresents a significant advancement in how developers interact with AI-powered coding assistants within Visual StudioCode.MCP, or Model Context Protocol, is an open standard ..."\n}', annotations=None, meta=None), TextContent(type='text', text='{\n  "title": "How to build MCP Servers and Test Locally from Scratch",\n  "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fdev.to%2Fdeveloper_harsh%2Fhow%2Dto%2Dbuild%2Dmcp%2Dservers%2Dand%2Dtest%2Dlocally%2Dfrom%2Dscratch%2D3d4j&rut=555c4965867383cf7c9e59da01f4c7891c345ff42a77bf731e98c7c515c6c6e4",\n  "snippet": "How to Build aMCPServerThere are 2 ways to build aMCPServer, using Python SDK or JavaScript SDK, for sake of simplicity, I will stick to Python SDK. So, like any other good dev, let\'s create a separate work environment to keep things isolated. 1. Work Environment Setup We start by creating a project directory."\n}', annotations=None, meta=None), TextContent(type='text', text='{\n  "title": "Working with MCP Servers in VS Code - YouTube",\n  "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3DgQXnBKh5H28&rut=2364919f61daad77ca7fcfe45730bd35a6550e294f2f487ffdfbe18290c1e699",\n  "snippet": "This video provides a simple gui ...

# %%
for i in resp.content:
    print(i.text,"\n")
# Out:
# {
#   "title": "Use MCP servers in VS Code - Visual Studio Code",
#   "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fcode.visualstudio.com%2Fdocs%2Fcopilot%2Fcustomization%2Fmcp%2Dservers&rut=1573ce17ef141aa0e1cea917c9f9326fd7194158c250f5de44fda89bb49a9f63",
#   "snippet": "Learn how to configure and use Model Context Protocol (MCP)serverswith GitHub Copilot in Visual StudioCode."
# }
#
# {
#   "title": "10 Microsoft MCP Servers to Accelerate Your Development Workflow",
#   "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fdeveloper.microsoft.com%2Fblog%2F10%2Dmicrosoft%2Dmcp%2Dservers%2Dto%2Daccelerate%2Dyour%2Ddevelopment%2Dworkflow&rut=f217d48669387a2592b08015774f7e018a8562ecd0f30c4aa8c9ebbe6bc2d020",
#   "snippet": "Here are 10MCPserversthat Microsoft has built that we've found particularly useful in our daily work - tools that solve real problems and speed up common development tasks. This isn't a comprehensive ranking, but rather a practical guide based on our team's experience with theseserversin real-world scenarios."
# }
#
# {
#   "title": "How to add 100+ MCP servers to VS Code in minutes",
#   "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fcomposio.dev%2Fblog%2Fhow%2Dto%2Dadd%2D100%2Dmcp%2Dservers%2Dto%2Dvs%2Dcode%2Din%2Dminutes&rut=d6f2fd3e131ad2e83dc71095d53ff4026cc7b305c3d3fbd86fff5cea3a57a015",
#   "snippet": "2. EnableMCPin VSCodeVSCode, by default, has theMCPserverenabled. To verify hit CTRL+SHIFT+P (Windows & Linux) / CMD+SHIFT+P (Mac) and searchMCP. 3. Add LocalMCPServersto VSCodeClickMCP: AddMCPServer& Select Command (stdio). Now follow the instructions carefully on all tabs! → Enter Command: Enter the command to run theserver."
# }
#
# {
#   "title": "GitHub - microsoft/azure-devops-mcp: The MCP server for Azure DevOps ...",
#   "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fgithub.com%2Fmicrosoft%2Fazure%2Ddevops%2Dmcp&rut=48ec0564a15b428286132156481d3a5c5085f202558db58e40aa17532f7e0239",
#   "snippet": "Easily install the Azure DevOpsMCPServerfor VSCodeor VSCodeInsiders: This TypeScript project provides a localMCPserverfor Azure DevOps, enabling you to perform a wide range of Azure DevOps tasks directly from yourcodeeditor."
# }
#
# {
#   "title": "How to Set Up and Use VSCode MCP Server - Medium",
#   "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fmedium.com%2Ftowards%2Dagi%2Fhow%2Dto%2Dset%2Dup%2Dand%2Duse%2Dvscode%2Dmcp%2Dserver%2D352c1e6f42e9&rut=61173c33488416f3a70ba5d40352d65d380043bba2b421c2cd1e799939532d53",
#   "snippet": "VSCodeMCPServerrepresents a significant advancement in how developers interact with AI-powered coding assistants within Visual StudioCode.MCP, or Model Context Protocol, is an open standard ..."
# }
#
# {
#   "title": "How to build MCP Servers and Test Locally from Scratch",
#   "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fdev.to%2Fdeveloper_harsh%2Fhow%2Dto%2Dbuild%2Dmcp%2Dservers%2Dand%2Dtest%2Dlocally%2Dfrom%2Dscratch%2D3d4j&rut=555c4965867383cf7c9e59da01f4c7891c345ff42a77bf731e98c7c515c6c6e4",
#   "snippet": "How to Build aMCPServerThere are 2 ways to build aMCPServer, using Python SDK or JavaScript SDK, for sake of simplicity, I will stick to Python SDK. So, like any other good dev, let's create a separate work environment to keep things isolated. 1. Work Environment Setup We start by creating a project directory."
# }
#
# {
#   "title": "Working with MCP Servers in VS Code - YouTube",
#   "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3DgQXnBKh5H28&rut=2364919f61daad77ca7fcfe45730bd35a6550e294f2f487ffdfbe18290c1e699",
#   "snippet": "This video provides a simple guide to using Visual StudioCodefor managingMCP(Model Context Protocol)servers. I'll demonstrate two different methods for creating a newMCPserverand show you ..."
# }
#
# {
#   "title": "Setting up MCP Servers in Visual Studio Code | Prompt Genius",
#   "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fpromptgenius.net%2Fmcp%2Fimplementation%2Dguide%2Fvscode&rut=c59129051e74f0981e685c58dd5809b5f1d5cb0161910bb9cab61e6a3c896723",
#   "snippet": "Model Context Protocol (MCP) enables AI models to interact with external tools and services through a unified interface. This guide will walk you through setting upMCPserversin Visual StudioCodeto enhance your GitHub Copilot experience."
# }
#
# {
#   "title": "How to Build an MCP Server: Step-by-Step with Code Examples",
#   "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Fblog.openreplay.com%2Fbuild%2Dmcp%2Dserver%2Dstep%2Dby%2Dstep%2Dcode%2Dexamples%2F&rut=aa29b979a563aaf4e692d9eb2b7d9588c1eff1be7bff471791b9cf4f8ad64ce7",
#   "snippet": "Key TakeawaysMCPserversallow AI models to interact with external systems through standardized resources and tools. You can build anMCPserverin Python using the official SDK. A minimalworkingservercan expose both read-only data (resources) and executable actions (tools). Security and error handling are critical for production deployments."
# }
#
# {
#   "title": "Use MCP Servers - Visual Studio (Windows) | Microsoft Learn",
#   "url": "//duckduckgo.com/l/?uddg=https%3A%2F%2Flearn.microsoft.com%2Fen%2Dus%2Fvisualstudio%2Fide%2Fmcp%2Dservers%3Fview%3Dvisualstudio&rut=6d7e7ee3c0fbb2fab072553683477e18d447a7c4521800f396bd6868c75daa6f",
#   "snippet": "Learn how to addMCPserversin Visual Studio to extend GitHub Copilot agent capabilities, set upmcp.json, and manage tool permissions."
# }
